# %% [markdown]
# #### LangChain Demo

# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
# Checking ig env variables are loaded or not 
import os 
print(os.getenv("GEMINI_API_KEY"))
# Out:
# AIzaSyAbiFeBe8RylPPZuuAc-_Yq9qVPt8Ht66s

# %%
import langchain_google_genai as gemini
llm = gemini.ChatGoogleGenerativeAI(model="gemini-3-flash-preview")
res = llm.invoke("who is ajay nagar")
res.content
# Out:
# [{'type': 'text',
# ...

# %%
print(res.content[0]['text'])
# Out:
# **Ajay Nagar**, better known by his online alias **CarryMinati**, is a prominent Indian YouTuber, streamer, and social media personality from Faridabad, India.
#
# He is widely considered one of the most influential digital creators in India. Here are the key facts about him:
#
# ### 1. Rise to Fame
# Ajay started his YouTube journey at the age of 10. He initially posted football tutorials and later moved to gaming videos and mimicry (specifically of Sunny Deol). He eventually found his niche in **"roasting"**—a style of video where he provides satirical and often aggressive commentary on viral videos, social media trends, and other internet personalities.
#
# ### 2. YouTube Channels
# *   **CarryMinati:** This is his main channel, where he posts his highly produced comedy skits and roast videos. As of 2024, he is the **most-subscribed individual YouTuber in India** (and Asia), with over 40 million subscribers.
# ...
