# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt

# %%
x , y = make_regression(n_samples=100,n_features=1,n_informative=1,noise=1,random_state=4)

# %%
x
